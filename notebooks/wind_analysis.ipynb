# %%
import os
from dotenv import load_dotenv
load_dotenv('../.env')
from pathlib import Path
PATH_WIND = Path(os.environ.get('PATH_WIND'))

# %%
import geopandas as gpd
import pandas as pd
import plotly_express as px
import plotly.graph_objects as go
from typing import List

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Analysis
#
# We would like some basic statistics, for instance:
# 1. Comparisons between countries regarding output, area, number of turbines, if possible normalised with population size.
# 2. Temporal trends.
# 3. A detailed overview of company shares in wind farms. For this we would probably need Neo4J to query the ownership graph, or simplify this graph to a table.
# 4. Perform linear regressions on costs of wind farms, because some data is lacking.
# 5. Assess how much power is sold through PPAs

# %%
# Import windfarm shapes
wind = gpd.read_file(PATH_WIND.joinpath('gis', 'windfarms_v1.geojson'))
                     
# Import company data from Aleph
cw = pd.read_csv(PATH_WIND.joinpath('aleph', 'company_windfarm.csv'))

# Merge files
df = pd.merge(cw,
              wind[['mps_uuid', 'geometry']],
              on='mps_uuid',
              how='left')

# Convert to geopandas
gdf = gpd.GeoDataFrame(df, geometry='geometry', crs=4326)

# %% [markdown]
# ### Stap 1: Nederland, bestaande windparken
#
# Dit zijn de Nederlandse windparken die in bedrijf zijn.

# %%
nl_operational = wind[(wind.country=='nl') & (wind.status == 'OPERATIONAL')].copy()
nl_operational[['name', 'geometry', 'capacity_mw']].explore(tiles='CartoDB Positron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_833078bdab54e71cb93a437c38436113 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_833078bdab54e71cb93a437c38436113&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_833078bdab54e71cb93a437c38436113 = L.map(
#                 &quot;map_833078bdab54e71cb93a437c38436113&quot;,
#                 {
#                     center: [52.822630000000004, 4.4330712],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_833078bdab54e71cb93a437c38436113);
#
#
#
#
#
#             var tile_layer_b401f85ca07b29a600c444806b736495 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_833078bdab54e71cb93a437c38436113);
#
#
#             map_833078bdab54e71cb93a437c38436113.fitBounds(
#                 [[51.570274, 2.770846], [54.074986, 6.0952964]],
#                 {}
#             );
#
#
#         function geo_json_0b39276c56d6898825de7dee9488bf1b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0b39276c56d6898825de7dee9488bf1b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0b39276c56d6898825de7dee9488bf1b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0b39276c56d6898825de7dee9488bf1b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0b39276c56d6898825de7dee9488bf1b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0b39276c56d6898825de7dee9488bf1b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0b39276c56d6898825de7dee9488bf1b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0b39276c56d6898825de7dee9488bf1b = L.geoJson(null, {
#                 onEachFeature: geo_json_0b39276c56d6898825de7dee9488bf1b_onEachFeature,
#
#                 style: geo_json_0b39276c56d6898825de7dee9488bf1b_styler,
#                 pointToLayer: geo_json_0b39276c56d6898825de7dee9488bf1b_pointToLayer
#         });
#
#         function geo_json_0b39276c56d6898825de7dee9488bf1b_add (data) {
#             geo_json_0b39276c56d6898825de7dee9488bf1b
#                 .addData(data)
#                 .addTo(map_833078bdab54e71cb93a437c38436113);
#         }
#             geo_json_0b39276c56d6898825de7dee9488bf1b_add({&quot;bbox&quot;: [2.770846, 51.570274, 6.0952964, 54.074986], &quot;features&quot;: [{&quot;bbox&quot;: [2.8874705, 51.599667, 3.0351129, 51.72571], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[3.0080383, 51.696087], [3.0070958, 51.696144], [3.0061617, 51.69624], [3.0052397, 51.696373], [3.0043337, 51.696545], [3.0034475, 51.69675], [3.002832, 51.696922], [2.9871159, 51.701508], [2.9868689, 51.70158], [2.9860337, 51.70186], [2.9852295, 51.70217], [2.9846702, 51.70242], [2.9844596, 51.70251], [2.9837275, 51.702885], [2.9830363, 51.70329], [2.9823887, 51.703716], [2.981788, 51.70417], [2.981236, 51.70465], [2.9807358, 51.70515], [2.9802892, 51.70567], [2.979898, 51.706203], [2.9795642, 51.706757]

# %% [markdown]
# ## Stap 2: Nederland, met toekomstige plannen en parken in aanbouw

# %%
def plot_plans(df: pd.DataFrame,
               country: str,
               exclude: List[str]):
    
    df = df[(df.country==country) & (~df.status.isin(exclude))].copy()
    df['color'] = df.status.apply(lambda x: '#C62828' if x in ['OPERATIONAL'] else '#283593')
    Map = df[['name', 'status', 'capacity_mw', 'geometry']].explore(tiles='CartoDB Positron',
                                                                    color=df.color)
    capacity = df.capacity_mw.sum()
    
    return Map, [capacity]

# %%
exclude = ['AREA_UNDER_STATE_INVESTIGATION']

Map, stats = plot_plans(wind, 'nl', exclude)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bb491a29f5ecb823796a1583e549ed8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bb491a29f5ecb823796a1583e549ed8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bb491a29f5ecb823796a1583e549ed8 = L.map(
#                 &quot;map_3bb491a29f5ecb823796a1583e549ed8&quot;,
#                 {
#                     center: [52.981877, 4.4330712],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3bb491a29f5ecb823796a1583e549ed8);
#
#
#
#
#
#             var tile_layer_a36fae36d426dd7be47c247bfc8aaef6 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3bb491a29f5ecb823796a1583e549ed8);
#
#
#             map_3bb491a29f5ecb823796a1583e549ed8.fitBounds(
#                 [[51.570274, 2.770846], [54.39348, 6.0952964]],
#                 {}
#             );
#
#
#         function geo_json_5fe5d8b9235870a421f94dbd05a23b59_styler(feature) {
#             switch(feature.id) {
#                 case &quot;127&quot;: case &quot;159&quot;: case &quot;200&quot;: case &quot;211&quot;: case &quot;220&quot;: case &quot;235&quot;: case &quot;252&quot;: case &quot;309&quot;: case &quot;344&quot;: case &quot;350&quot;:
#                     return {&quot;color&quot;: &quot;#283593&quot;, &quot;fillColor&quot;: &quot;#283593&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#C62828&quot;, &quot;fillColor&quot;: &quot;#C62828&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5fe5d8b9235870a421f94dbd05a23b59_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5fe5d8b9235870a421f94dbd05a23b59_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5fe5d8b9235870a421f94dbd05a23b59_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5fe5d8b9235870a421f94dbd05a23b59_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5fe5d8b9235870a421f94dbd05a23b59.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5fe5d8b9235870a421f94dbd05a23b59_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5fe5d8b9235870a421f94dbd05a23b59 = L.geoJson(null, {
#                 onEachFeature: geo_json_5fe5d8b9235870a421f94dbd05a23b59_onEachFeature,
#
#                 style: geo_json_5fe5d8b9235870a421f94dbd05a23b59_styler,
#                 pointToLayer: geo_json_5fe5d8b9235870a421f94dbd05a23b59_pointToLayer
#         });
#
#         function geo_json_5fe5d8b9235870a421f94dbd05a23b59_add (data) {
#             geo_json_5fe5d8b9235870a421f94dbd05a23b59
#                 .addData(data)
#                 .addTo(map_3bb491a29f5ecb823796a1583e549ed8);
#         }
#             geo_json_5fe5d8b9235870a421f94dbd05a23b59_add({&quot;bbox&quot;: [2.770846, 51.570274, 6.0952964, 54.39348], &quot;features&quot;: [{&quot;bbox&quot;: [3.5275605, 52.927418, 3.920179, 53.111324], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[3.7993114, 52.927418], [3.5275605

# %% [markdown]
# ## Stap 3: Maar hoe zit het in andere landen?

# %% [markdown]
# ### Noorwegen - niet zo ver

# %%
Map, stats = plot_plans(wind, 'no', exclude)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8c3fdb7f2971dc27ca2b67edc9807e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8c3fdb7f2971dc27ca2b67edc9807e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8c3fdb7f2971dc27ca2b67edc9807e9 = L.map(
#                 &quot;map_c8c3fdb7f2971dc27ca2b67edc9807e9&quot;,
#                 {
#                     center: [63.907878115, 12.247314925],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c8c3fdb7f2971dc27ca2b67edc9807e9);
#
#
#
#
#
#             var tile_layer_be074348c74b2d9f9872ea16634b394d = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c8c3fdb7f2971dc27ca2b67edc9807e9);
#
#
#             map_c8c3fdb7f2971dc27ca2b67edc9807e9.fitBounds(
#                 [[56.483887, 2.21416136], [71.33186923, 22.28046849]],
#                 {}
#             );
#
#
#         function geo_json_040a994c8b86526d54707dc46c15b6ed_styler(feature) {
#             switch(feature.id) {
#                 case &quot;333&quot;: case &quot;334&quot;: case &quot;404&quot;:
#                     return {&quot;color&quot;: &quot;#C62828&quot;, &quot;fillColor&quot;: &quot;#C62828&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#283593&quot;, &quot;fillColor&quot;: &quot;#283593&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_040a994c8b86526d54707dc46c15b6ed_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_040a994c8b86526d54707dc46c15b6ed_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_040a994c8b86526d54707dc46c15b6ed_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_040a994c8b86526d54707dc46c15b6ed_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_040a994c8b86526d54707dc46c15b6ed.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_040a994c8b86526d54707dc46c15b6ed_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_040a994c8b86526d54707dc46c15b6ed = L.geoJson(null, {
#                 onEachFeature: geo_json_040a994c8b86526d54707dc46c15b6ed_onEachFeature,
#
#                 style: geo_json_040a994c8b86526d54707dc46c15b6ed_styler,
#                 pointToLayer: geo_json_040a994c8b86526d54707dc46c15b6ed_pointToLayer
#         });
#
#         function geo_json_040a994c8b86526d54707dc46c15b6ed_add (data) {
#             geo_json_040a994c8b86526d54707dc46c15b6ed
#                 .addData(data)
#                 .addTo(map_c8c3fdb7f2971dc27ca2b67edc9807e9);
#         }
#             geo_json_040a994c8b86526d54707dc46c15b6ed_add({&quot;bbox&quot;: [2.21416136, 56.483887, 22.28046849, 71.33186923], &quot;features&quot;: [{&quot;bbox&quot;: [22.23555273, 71.31744848, 22.28046849, 71.33186923], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[22.23555273, 71.31744848], [22.28046849, 71.31744848], [22.28046849, 71.33186923], [22.23555273, 71.33186923], [22.23555273, 71.31744848]]]], &quot;type&quot;

# %% [markdown]
# ### België evenmin

# %%
Map, stats = plot_plans(wind, 'be', exclude)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_480d03ea243b21a369bbab59dc49b88e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_480d03ea243b21a369bbab59dc49b88e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_480d03ea243b21a369bbab59dc49b88e = L.map(
#                 &quot;map_480d03ea243b21a369bbab59dc49b88e&quot;,
#                 {
#                     center: [51.614706999999996, 2.8937677500000003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_480d03ea243b21a369bbab59dc49b88e);
#
#
#
#
#
#             var tile_layer_c49e847e0cc7411d20007eb3f6a770ae = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_480d03ea243b21a369bbab59dc49b88e);
#
#
#             map_480d03ea243b21a369bbab59dc49b88e.fitBounds(
#                 [[51.4895, 2.7050076], [51.739914, 3.0825279]],
#                 {}
#             );
#
#
#         function geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#C62828&quot;, &quot;fillColor&quot;: &quot;#C62828&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_58dfbefaa5b40fdf7d339e0f21f5595e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_58dfbefaa5b40fdf7d339e0f21f5595e = L.geoJson(null, {
#                 onEachFeature: geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_onEachFeature,
#
#                 style: geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_styler,
#                 pointToLayer: geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_pointToLayer
#         });
#
#         function geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_add (data) {
#             geo_json_58dfbefaa5b40fdf7d339e0f21f5595e
#                 .addData(data)
#                 .addTo(map_480d03ea243b21a369bbab59dc49b88e);
#         }
#             geo_json_58dfbefaa5b40fdf7d339e0f21f5595e_add({&quot;bbox&quot;: [2.7050076, 51.4895, 3.0825279, 51.739914], &quot;features&quot;: [{&quot;bbox&quot;: [2.77378, 51.63259, 2.8392, 51.70647], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[2.81043, 51.70647], [2.8392, 51.68922], [2.83795, 51.68712], [2.8247, 51.69078], [2.82334, 51.6885], [2.82699, 51.6875], [2.7942, 51.63259], [2.79198, 51.63645], [2.77378, 51.64505], [2.81043, 51.70647]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;101&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;#C62828&quot;, &quot;capacity_mw&quot;: 165.0, &quot;name&quot;: &quot;BELWIND I

# %% [markdown]
# ### Maar Duitsland, met een hele kleine Noordzee, is een stuk verder

# %%
Map, stats = plot_plans(wind, 'de', exclude)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27ee097044b631c5f2482290305452c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27ee097044b631c5f2482290305452c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27ee097044b631c5f2482290305452c3 = L.map(
#                 &quot;map_27ee097044b631c5f2482290305452c3&quot;,
#                 {
#                     center: [54.48807, 9.85459065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_27ee097044b631c5f2482290305452c3);
#
#
#
#
#
#             var tile_layer_add3ba026ec68598b0be9276c498ef3d = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_27ee097044b631c5f2482290305452c3);
#
#
#             map_27ee097044b631c5f2482290305452c3.fitBounds(
#                 [[53.682, 5.529398], [55.29414, 14.1797833]],
#                 {}
#             );
#
#
#         function geo_json_9ad6917d477b30c18721c056fec970bf_styler(feature) {
#             switch(feature.id) {
#                 case &quot;90&quot;: case &quot;93&quot;: case &quot;96&quot;: case &quot;104&quot;: case &quot;111&quot;: case &quot;118&quot;: case &quot;138&quot;: case &quot;147&quot;: case &quot;152&quot;: case &quot;162&quot;: case &quot;168&quot;: case &quot;170&quot;: case &quot;172&quot;: case &quot;194&quot;: case &quot;208&quot;: case &quot;221&quot;: case &quot;233&quot;: case &quot;243&quot;: case &quot;268&quot;: case &quot;312&quot;: case &quot;325&quot;: case &quot;345&quot;: case &quot;355&quot;: case &quot;359&quot;: case &quot;373&quot;: case &quot;378&quot;: case &quot;382&quot;: case &quot;402&quot;:
#                     return {&quot;color&quot;: &quot;#C62828&quot;, &quot;fillColor&quot;: &quot;#C62828&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#283593&quot;, &quot;fillColor&quot;: &quot;#283593&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9ad6917d477b30c18721c056fec970bf_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9ad6917d477b30c18721c056fec970bf_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_9ad6917d477b30c18721c056fec970bf_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9ad6917d477b30c18721c056fec970bf_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_9ad6917d477b30c18721c056fec970bf.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9ad6917d477b30c18721c056fec970bf_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9ad6917d477b30c18721c056fec970bf = L.geoJson(null, {
#                 onEachFeature: geo_json_9ad6917d477b30c18721c056fec970bf_onEachFeature,
#
#                 style: geo_json_9ad6917d477b30c18721c056fec970bf_styler,
#                 pointToLayer: geo_json_9ad6917d477b30c18721c056fec970bf_pointToLayer
#         });
#
#         function geo_json_9ad6917d477b30c18721c056fec970bf_add (data) {
#             geo_json_9ad6917d477b30c18721c056fec970bf

# %% [markdown]
# ### En Denemarken helemaal

# %%
Map, stats = plot_plans(wind, 'dk', exclude)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d60914e69d2deebc0a191a767edca6a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d60914e69d2deebc0a191a767edca6a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d60914e69d2deebc0a191a767edca6a5 = L.map(
#                 &quot;map_d60914e69d2deebc0a191a767edca6a5&quot;,
#                 {
#                     center: [56.096098299999994, 10.953654995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d60914e69d2deebc0a191a767edca6a5);
#
#
#
#
#
#             var tile_layer_977fe392d3d2f104b6478fef1dbb1312 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d60914e69d2deebc0a191a767edca6a5);
#
#
#             map_d60914e69d2deebc0a191a767edca6a5.fitBounds(
#                 [[54.4801873, 5.65202383], [57.7120093, 16.25528616]],
#                 {}
#             );
#
#
#         function geo_json_938077a7f1a5a0ff2b289170af8ba983_styler(feature) {
#             switch(feature.id) {
#                 case &quot;157&quot;: case &quot;213&quot;: case &quot;230&quot;: case &quot;232&quot;: case &quot;237&quot;: case &quot;250&quot;: case &quot;290&quot;: case &quot;294&quot;: case &quot;300&quot;: case &quot;319&quot;: case &quot;370&quot;: case &quot;376&quot;: case &quot;395&quot;:
#                     return {&quot;color&quot;: &quot;#C62828&quot;, &quot;fillColor&quot;: &quot;#C62828&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#283593&quot;, &quot;fillColor&quot;: &quot;#283593&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_938077a7f1a5a0ff2b289170af8ba983_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_938077a7f1a5a0ff2b289170af8ba983_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_938077a7f1a5a0ff2b289170af8ba983_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_938077a7f1a5a0ff2b289170af8ba983_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_938077a7f1a5a0ff2b289170af8ba983.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_938077a7f1a5a0ff2b289170af8ba983_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_938077a7f1a5a0ff2b289170af8ba983 = L.geoJson(null, {
#                 onEachFeature: geo_json_938077a7f1a5a0ff2b289170af8ba983_onEachFeature,
#
#                 style: geo_json_938077a7f1a5a0ff2b289170af8ba983_styler,
#                 pointToLayer: geo_json_938077a7f1a5a0ff2b289170af8ba983_pointToLayer
#         });
#
#         function geo_json_938077a7f1a5a0ff2b289170af8ba983_add (data) {
#             geo_json_938077a7f1a5a0ff2b289170af8ba983
#                 .addData(data)
#                 .addTo(map_d60914e69d2deebc0a191a767edca6a5);
#         }
#             geo_json_938077a7f1a5a0ff2b289170af8ba983_add({&quot;bbox&quot;: [5.65202383, 54.4801873, 16.25528616, 57.7120093], &quot;features&quot;: [{&quot;bbox&quot;: [10.52607565, 54.85723839, 10.53539065

# %% [markdown]
# ### En het Verenigd Koninkrijk spant de kroon

# %%
Map, stats = plot_plans(wind, 'gb', exclude)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9a11a64a58eb1c88e66b56b0a517b21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9a11a64a58eb1c88e66b56b0a517b21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9a11a64a58eb1c88e66b56b0a517b21 = L.map(
#                 &quot;map_e9a11a64a58eb1c88e66b56b0a517b21&quot;,
#                 {
#                     center: [55.43744021, -1.9167291999999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e9a11a64a58eb1c88e66b56b0a517b21);
#
#
#
#
#
#             var tile_layer_3a8c63e0adbbbbde21a44a379afd2455 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9a11a64a58eb1c88e66b56b0a517b21);
#
#
#             map_e9a11a64a58eb1c88e66b56b0a517b21.fitBounds(
#                 [[50.345, -6.9781837], [60.52988042, 3.1447253]],
#                 {}
#             );
#
#
#         function geo_json_78b965c6df9d21bd7d1c3ed6ff38c994_styler(feature) {
#             switch(feature.id) {
#                 case &quot;92&quot;: case &quot;120&quot;: case &quot;132&quot;: case &quot;133&quot;: case &quot;140&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;148&quot;: case &quot;160&quot;: case &quot;166&quot;: case &quot;175&quot;: case &quot;180&quot;: case &quot;183&quot;: case &quot;190&quot;: case &quot;195&quot;: case &quot;199&quot;: case &quot;201&quot;: case &quot;204&quot;: case &quot;209&quot;: case &quot;210&quot;: case &quot;215&quot;: case &quot;223&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;228&quot;: case &quot;229&quot;: case &quot;239&quot;: case &quot;240&quot;: case &quot;256&quot;: case &quot;259&quot;: case &quot;261&quot;: case &quot;264&quot;: case &quot;274&quot;: case &quot;284&quot;: case &quot;313&quot;: case &quot;320&quot;: case &quot;327&quot;: case &quot;328&quot;: case &quot;329&quot;: case &quot;330&quot;: case &quot;332&quot;: case &quot;347&quot;: case &quot;348&quot;: case &quot;357&quot;: case &quot;361&quot;: case &quot;367&quot;: case &quot;372&quot;: case &quot;374&quot;: case &quot;377&quot;: case &quot;385&quot;: case &quot;391&quot;: case &quot;410&quot;:
#                     return {&quot;color&quot;: &quot;#C62828&quot;, &quot;fillColor&quot;: &quot;#C62828&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#283593&quot;, &quot;fillColor&quot;: &quot;#283593&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_78b965c6df9d21bd7d1c3ed6ff38c994_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_78b965c6df9d21bd7d1c3ed6ff38c994_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_78b965c6df9d21bd7d1c3ed6ff38c994_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_78b965c6df9d21bd7d1c3ed6ff38c994_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_78b965c6df9d21bd7d1c3ed6ff38c994.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_78b965c6df9d21bd7d1c3ed6ff38c994_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);

# %% [markdown]
# ## Groei van het vermogen
#
# De bestaande en geplande hoeveelheid energie groeit de komende jaren enorm.

# %%
def plot_power(df: pd.DataFrame,     
               country: str,
               exclude: List[str],
               column: str = 'capacity_mw',
               cumulative: bool = True):
    
    df = df[~df.status.isin(exclude)]
    
    if country == 'all':
        df = df.groupby(['country','year'])[column].sum().reset_index()
        if cumulative:
            df = df.sort_values(by='year')
            df['cumsum'] = df[column].cumsum()
            return px.line(data_frame=df,
                           x='year',
                           y='cumsum',
                           title='Cumulative additional output per year for all countries'
                          )
        else:
            return px.bar(data_frame=df,
                           x='year',
                           y=[column],
                           color='country',
                           title='Additional capacity per year per country')
        
    else:
        df=df[df.country == country].copy()
        df = df.groupby('year')[column].sum().reset_index()
        if cumulative:
            df['cumsum'] = df[column].cumsum()
            return px.line(data_frame=df,
                           x='year',
                           y='cumsum',
                           title=f'Cumulative additional output per year for {country}')
        else:
            return px.bar(data_frame=df,
                          x='year',
                          y=[column],
                          title=f'Additonal capacity per year for {country}')

# %% [markdown]
# ### Alle Noordzeelanden cumulatief
#
# In 2030 vindt er een enorme sprong plaats. Dit is wel op voorwaarde dat alle plannen doorgaan en de beoogde capaciteit ook wordt gehaald.

# %%
fig = plot_power(df, 'all', exclude, 'capacity_mw', cumulative=True)
fig.add_vline(x='2023-01-01', line_width=1, line_dash='dash', line_color='red')

# %% [markdown]
# ### Alle Noordzeelanden afzonderlijk
#
# Het grootste deel van de groei komt voor rekening van het Verenigd Koninkrijk en Duitsland.

# %%
fig = px.line(df.groupby(['country','year']).capacity_mw.sum().groupby(level=0).cumsum().reset_index(),
              x='year',
              y='capacity_mw',
              color='country')

fig.add_vline(x='2023-01-01', 
              line_width=1, 
              line_dash='dash', 
              line_color='red')

# %% [markdown]
# ## Verandering over tijd
#
# Je ziet pas echt hoeveel windparken er op zee bijkomen, als je de gebieden over tijd op een kaart zet.

# %% [markdown]
# ## Vermogen per hoofd van de bevolking

# %%
pop = {'nl': 17800000,
       'dk': 5940000,
       'de': 84430000,
       'gb': 67020000,
       'no': 5500000,
       'be': 11690000}

# %%
df['pop'] = df.country.map(pop)
df['capacity_pop'] = df.capacity_mw / (df['pop'] / 1000000)

# %%
fig = px.line(df.groupby(['country','year']).capacity_pop.sum().groupby(level=0).cumsum().reset_index(),
              x='year',
              y='capacity_pop',
              color='country',
              title='Output of North Sea wind parks per country per million inhabitants')

fig.add_vline(x='2023-01-01', 
              line_width=1, 
              line_dash='dash', 
              line_color='red')

# %% [markdown]
# <video width="600" height="450"
#        src="./timelapse_windfarms.mp4"
#        controls>
# </video>

# %% [markdown]
# ## Bedrijven
#
# Ook Nederlandse bedrijven tellen niet echt mee, zelfs niet in onze eigen Noordzee.

# %%
selection = gdf.groupby(['jurisdiction', 'country', 'company']).agg({'output_company_mw_lower': 'sum',
                                                   'output_company_mw_upper': 'sum'}).reset_index()

# %%
fig = px.bar(selection.groupby(['jurisdiction'])\
           .agg({'output_company_mw_lower': 'sum',
                 'output_company_mw_upper': 'sum'})\
           .reset_index()\
           .sort_values(by='output_company_mw_lower', 
                        ascending=False),
           x='jurisdiction',
           y=['output_company_mw_lower', 'output_company_mw_upper'],
           barmode='group',
           title='Output of North Sea wind parks per company HQ jurisdiction',
           labels=dict(value='Output in MW', jurisdiction='Country HQ company'))

newnames = {'output_company_mw_lower': 'Lower limit MW', 'output_company_mw_upper': 'Upper limit MW'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name]))

fig.show()

# %%
fig = go.Figure(go.Parcats(
    dimensions=[
        {'label': 'country_company', 'values': selection.jurisdiction},
        {'label': 'country_asset', 'values': selection.country}
    ],
    counts=selection.output_company_mw_upper
                          ))

fig.show()
